# %% [markdown]
# <a href="https://colab.research.google.com/github/Narendraiitg/ResistorSorter/blob/main/Resistor_Sorter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import sys
from google.colab.patches import cv2_imshow

# %%
img= cv.imread('/content/starynight.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=454x300 at 0x7FF61E064DD0>
